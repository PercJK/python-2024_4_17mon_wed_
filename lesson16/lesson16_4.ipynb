# %%
import requests
from requests import Response
aqi_url = 'https://data.moenv.gov.tw/api/v2/aqx_p_488?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate desc&format=JSON'

res: Response = requests.get(aqi_url)
if res.status_code == 200:
    print('下載成功')
else:
    print('下載失敗')

#自訂的欄位驗証
from pydantic import BaseModel, Field, field_validator

class Site(BaseModel):
    site_name: str = Field(alias='sitename')
    county: str
    aqi: int
    status: str
    pm25: float = Field(alias='pm2.5')
    so2: float
    co: float

    @field_validator('pm25', 'so2', 'co', mode='before')
    @classmethod
    def whitespace_to_zero(cls, value: str) -> str:
        if value == '':
            return '0.0'
        else:
            return value

class AQI(BaseModel):
    records: list[Site]

data: AQI = AQI.model_validate_json(res.text)
# Out:
# 下載成功

# %%
all_sites:list[dict] = data.model_dump()['records']
all_sites #python的基本資料結構
# Out:
# [{'site_name': '屏東(枋山)',
#   'county': '屏東縣',
#   'aqi': 27,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.3,
#   'co': 0.06},
#  {'site_name': '大甲（日南國小）',
#   'county': '臺中市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.6,
#   'co': 0.23},
#  {'site_name': '新北(樹林)',
#   'county': '新北市',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 20.0,
#   'so2': 1.0,
#   'co': 0.17},
#  {'site_name': '屏東（琉球）',
#   'county': '屏東縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.8,
#   'co': 0.28},
#  {'site_name': '臺南（麻豆）',
#   'county': '臺南市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.7,
#   'co': 0.12},
#  {'site_name': '高雄（湖內）',
#   'county': '高雄市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.0,
#   'co': 0.14},
#  {'site_name': '彰化（員林）',
#   'county': '彰化縣',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.7,
#   'co': 0.21},
#  {'site_name': '大城',
#   'county': '彰化縣',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.4,
#   'co': 0.03},
#  {'site_name': '富貴角',
#   'county': '新北市',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.3,
#   'co': 0.07},
#  {'site_name': '麥寮',
#   'county': '雲林縣',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.1,
#   'co': 0.1},
#  {'site_name': '關山',
#   'county': '臺東縣',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.4,
#   'co': 0.11},
#  {'site_name': '馬公',
#   'county': '澎湖縣',
#   'aqi': 20,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.8,
#   'co': 0.2},
#  {'site_name': '金門',
#   'county': '金門縣',
#   'aqi': 21,
#   'status': '良好',
#   'pm25': 3.0,
#   'so2': 1.2,
#   'co': 0.08},
#  {'site_name': '馬祖',
#   'county': '連江縣',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.3,
#   'co': 0.08},
#  {'site_name': '埔里',
#   'county': '南投縣',
#   'aqi': 56,
#   'status': '普通',
#   'pm25': 16.0,
#   'so2': 0.9,
#   'co': 0.24},
#  {'site_name': '復興',
#   'county': '高雄市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.7,
#   'co': 0.22},
#  {'site_name': '永和',
#   'county': '新北市',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 20.0,
#   'so2': 0.8,
#   'co': 0.39},
#  {'site_name': '竹山',
#   'county': '南投縣',
#   'aqi': 58,
#   'status': '普通',
#   'pm25': 17.0,
#   'so2': 1.0,
#   'co': 0.08},
#  {'site_name': '中壢',
#   'county': '桃園市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.1,
#   'co': 0.87},
#  {'site_name': '三重',
#   'county': '新北市',
#   'aqi': 58,
#   'status': '普通',
#   'pm25': 19.0,
#   'so2': 1.5,
#   'co': 1.28},
#  {'site_name': '冬山',
#   'county': '宜蘭縣',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 0.5,
#   'co': 0.34},
#  {'site_name': '宜蘭',
#   'county': '宜蘭縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.3,
#   'co': 0.36},
#  {'site_name': '陽明',
#   'county': '臺北市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.8,
#   'co': 0.12},
#  {'site_name': '花蓮',
#   'county': '花蓮縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.4,
#   'co': 0.25},
#  {'site_name': '臺東',
#   'county': '臺東縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.2,
#   'co': 0.18},
#  {'site_name': '恆春',
#   'county': '屏東縣',
#   'aqi': 27,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.9,
#   'co': 0.09},
#  {'site_name': '潮州',
#   'county': '屏東縣',
#   'aqi': -1,
#   'status': '',
#   'pm25': 7.0,
#   'so2': 0.9,
#   'co': 0.0},
#  {'site_name': '屏東',
#   'county': '屏東縣',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 2.0,
#   'co': 0.21},
#  {'site_name': '小港',
#   'county': '高雄市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.2,
#   'co': 0.19},
#  {'site_name': '前鎮',
#   'county': '高雄市',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.3},
#  {'site_name': '前金',
#   'county': '高雄市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.4,
#   'co': 0.15},
#  {'site_name': '左營',
#   'county': '高雄市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.7,
#   'co': 0.16},
#  {'site_name': '楠梓',
#   'county': '高雄市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.2,
#   'co': 0.19},
#  {'site_name': '林園',
#   'county': '高雄市',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.3,
#   'co': 0.1},
#  {'site_name': '大寮',
#   'county': '高雄市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.3,
#   'co': 0.11},
#  {'site_name': '鳳山',
#   'county': '高雄市',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.8,
#   'co': 0.4},
#  {'site_name': '仁武',
#   'county': '高雄市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.0,
#   'co': 0.2},
#  {'site_name': '橋頭',
#   'county': '高雄市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.1,
#   'co': 0.15},
#  {'site_name': '美濃',
#   'county': '高雄市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 2.8,
#   'co': 0.22},
#  {'site_name': '臺南',
#   'county': '臺南市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.0,
#   'co': 0.13},
#  {'site_name': '安南',
#   'county': '臺南市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.5,
#   'co': 0.18},
#  {'site_name': '善化',
#   'county': '臺南市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.6,
#   'co': 0.11},
#  {'site_name': '新營',
#   'county': '臺南市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.4,
#   'co': 0.23},
#  {'site_name': '嘉義',
#   'county': '嘉義市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.3,
#   'co': 0.15},
#  {'site_name': '臺西',
#   'county': '雲林縣',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.4,
#   'co': 0.09},
#  {'site_name': '朴子',
#   'county': '嘉義縣',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.9,
#   'co': 0.0},
#  {'site_name': '新港',
#   'county': '嘉義縣',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.0,
#   'co': 0.1},
#  {'site_name': '崙背',
#   'county': '雲林縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.7,
#   'co': 0.08},
#  {'site_name': '斗六',
#   'county': '雲林縣',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.5,
#   'co': 0.23},
#  {'site_name': '南投',
#   'county': '南投縣',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 0.7,
#   'co': 0.18},
#  {'site_name': '二林',
#   'county': '彰化縣',
#   'aqi': 51,
#   'status': '普通',
#   'pm25': 14.0,
#   'so2': 1.3,
#   'co': 0.09},
#  {'site_name': '線西',
#   'county': '彰化縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.7,
#   'co': 0.09},
#  {'site_name': '彰化',
#   'county': '彰化縣',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.8,
#   'co': 0.15},
#  {'site_name': '西屯',
#   'county': '臺中市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.4,
#   'co': 0.14},
#  {'site_name': '忠明',
#   'county': '臺中市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.5,
#   'co': 0.22},
#  {'site_name': '大里',
#   'county': '臺中市',
#   'aqi': 43,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.4,
#   'co': 0.18},
#  {'site_name': '沙鹿',
#   'county': '臺中市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.3,
#   'co': 0.16},
#  {'site_name': '豐原',
#   'county': '臺中市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.4,
#   'co': 0.23},
#  {'site_name': '三義',
#   'county': '苗栗縣',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.4,
#   'co': 0.15},
#  {'site_name': '苗栗',
#   'county': '苗栗縣',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.3,
#   'co': 0.11},
#  {'site_name': '頭份',
#   'county': '苗栗縣',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.7,
#   'co': 0.15},
#  {'site_name': '新竹',
#   'county': '新竹市',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.4,
#   'co': 0.16},
#  {'site_name': '竹東',
#   'county': '新竹縣',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.5,
#   'co': 0.14},
#  {'site_name': '湖口',
#   'county': '新竹縣',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 0.0,
#   'co': 0.09},
#  {'site_name': '龍潭',
#   'county': '桃園市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.9,
#   'co': 0.11},
#  {'site_name': '平鎮',
#   'county': '桃園市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.3,
#   'co': 0.13},
#  {'site_name': '觀音',
#   'county': '桃園市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.0,
#   'co': 0.07},
#  {'site_name': '大園',
#   'county': '桃園市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.0,
#   'co': 0.12},
#  {'site_name': '桃園',
#   'county': '桃園市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.3,
#   'co': 0.2},
#  {'site_name': '大同',
#   'county': '臺北市',
#   'aqi': 59,
#   'status': '普通',
#   'pm25': 18.0,
#   'so2': 1.0,
#   'co': 1.5},
#  {'site_name': '松山',
#   'county': '臺北市',
#   'aqi': 55,
#   'status': '普通',
#   'pm25': 16.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '古亭',
#   'county': '臺北市',
#   'aqi': 49,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.5,
#   'co': 0.21},
#  {'site_name': '萬華',
#   'county': '臺北市',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.8,
#   'co': 0.41},
#  {'site_name': '中山',
#   'county': '臺北市',
#   'aqi': 53,
#   'status': '普通',
#   'pm25': 14.0,
#   'so2': 1.1,
#   'co': 0.66},
#  {'site_name': '士林',
#   'county': '臺北市',
#   'aqi': 55,
#   'status': '普通',
#   'pm25': 16.0,
#   'so2': 1.0,
#   'co': 0.15},
#  {'site_name': '淡水',
#   'county': '新北市',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.2,
#   'co': 0.1},
#  {'site_name': '林口',
#   'county': '新北市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.0,
#   'co': 0.15},
#  {'site_name': '菜寮',
#   'county': '新北市',
#   'aqi': 51,
#   'status': '普通',
#   'pm25': 14.0,
#   'so2': 1.3,
#   'co': 0.31},
#  {'site_name': '新莊',
#   'county': '新北市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.6,
#   'co': 0.14},
#  {'site_name': '板橋',
#   'county': '新北市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.1,
#   'co': 0.22},
#  {'site_name': '土城',
#   'county': '新北市',
#   'aqi': 67,
#   'status': '普通',
#   'pm25': 24.0,
#   'so2': 0.2,
#   'co': 0.2},
#  {'site_name': '新店',
#   'county': '新北市',
#   'aqi': 58,
#   'status': '普通',
#   'pm25': 18.0,
#   'so2': 0.8,
#   'co': 0.21},
#  {'site_name': '萬里',
#   'county': '新北市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 0.5,
#   'co': 0.18},
#  {'site_name': '汐止',
#   'county': '新北市',
#   'aqi': 54,
#   'status': '普通',
#   'pm25': 17.0,
#   'so2': 1.2,
#   'co': 0.36},
#  {'site_name': '基隆',
#   'county': '基隆市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.0,
#   'co': 0.35},
#  {'site_name': '屏東(枋山)',
#   'county': '屏東縣',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.4,
#   'co': 0.08},
#  {'site_name': '大甲（日南國小）',
#   'county': '臺中市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.3,
#   'co': 0.19},
#  {'site_name': '新北(樹林)',
#   'county': '新北市',
#   'aqi': 56,
#   'status': '普通',
#   'pm25': 19.0,
#   'so2': 1.0,
#   'co': 0.15},
#  {'site_name': '屏東（琉球）',
#   'county': '屏東縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.5,
#   'co': 0.11},
#  {'site_name': '臺南（麻豆）',
#   'county': '臺南市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.6,
#   'co': 0.11},
#  {'site_name': '高雄（湖內）',
#   'county': '高雄市',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.0,
#   'co': 0.1},
#  {'site_name': '彰化（員林）',
#   'county': '彰化縣',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.9,
#   'co': 0.19},
#  {'site_name': '大城',
#   'county': '彰化縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.4,
#   'co': 0.03},
#  {'site_name': '富貴角',
#   'county': '新北市',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.3,
#   'co': 0.07},
#  {'site_name': '麥寮',
#   'county': '雲林縣',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.2,
#   'co': 0.1},
#  {'site_name': '關山',
#   'county': '臺東縣',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.6,
#   'co': 0.09},
#  {'site_name': '馬公',
#   'county': '澎湖縣',
#   'aqi': 19,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.9,
#   'co': 0.16},
#  {'site_name': '金門',
#   'county': '金門縣',
#   'aqi': 20,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 1.2,
#   'co': 0.08},
#  {'site_name': '馬祖',
#   'county': '連江縣',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.3,
#   'co': 0.08},
#  {'site_name': '埔里',
#   'county': '南投縣',
#   'aqi': 56,
#   'status': '普通',
#   'pm25': 14.0,
#   'so2': 0.9,
#   'co': 0.2},
#  {'site_name': '復興',
#   'county': '高雄市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.6,
#   'co': 0.21},
#  {'site_name': '永和',
#   'county': '新北市',
#   'aqi': 58,
#   'status': '普通',
#   'pm25': 16.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '竹山',
#   'county': '南投縣',
#   'aqi': 61,
#   'status': '普通',
#   'pm25': 22.0,
#   'so2': 1.1,
#   'co': 0.09},
#  {'site_name': '中壢',
#   'county': '桃園市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.0,
#   'co': 0.6},
#  {'site_name': '三重',
#   'county': '新北市',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 16.0,
#   'so2': 1.4,
#   'co': 0.91},
#  {'site_name': '冬山',
#   'county': '宜蘭縣',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.5,
#   'co': 0.29},
#  {'site_name': '宜蘭',
#   'county': '宜蘭縣',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.2,
#   'co': 0.26},
#  {'site_name': '陽明',
#   'county': '臺北市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.9,
#   'co': 0.12},
#  {'site_name': '花蓮',
#   'county': '花蓮縣',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.3,
#   'co': 0.17},
#  {'site_name': '臺東',
#   'county': '臺東縣',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.2,
#   'co': 0.14},
#  {'site_name': '恆春',
#   'county': '屏東縣',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.9,
#   'co': 0.09},
#  {'site_name': '潮州',
#   'county': '屏東縣',
#   'aqi': -1,
#   'status': '',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '屏東',
#   'county': '屏東縣',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.0,
#   'co': 0.16},
#  {'site_name': '小港',
#   'county': '高雄市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.8,
#   'co': 0.15},
#  {'site_name': '前鎮',
#   'county': '高雄市',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '前金',
#   'county': '高雄市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.3,
#   'co': 0.13},
#  {'site_name': '左營',
#   'county': '高雄市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.7,
#   'co': 0.13},
#  {'site_name': '楠梓',
#   'county': '高雄市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.3,
#   'co': 0.12},
#  {'site_name': '林園',
#   'county': '高雄市',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.1,
#   'co': 0.09},
#  {'site_name': '大寮',
#   'county': '高雄市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.3,
#   'co': 0.13},
#  {'site_name': '鳳山',
#   'county': '高雄市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.9,
#   'co': 0.32},
#  {'site_name': '仁武',
#   'county': '高雄市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.0,
#   'co': 0.15},
#  {'site_name': '橋頭',
#   'county': '高雄市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.1,
#   'co': 0.1},
#  {'site_name': '美濃',
#   'county': '高雄市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 2.5,
#   'co': 0.23},
#  {'site_name': '臺南',
#   'county': '臺南市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.0,
#   'co': 0.14},
#  {'site_name': '安南',
#   'county': '臺南市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.6,
#   'co': 0.16},
#  {'site_name': '善化',
#   'county': '臺南市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.4,
#   'co': 0.08},
#  {'site_name': '新營',
#   'county': '臺南市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.4,
#   'co': 0.17},
#  {'site_name': '嘉義',
#   'county': '嘉義市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.1,
#   'co': 0.14},
#  {'site_name': '臺西',
#   'county': '雲林縣',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.5,
#   'co': 0.09},
#  {'site_name': '朴子',
#   'county': '嘉義縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 1.1,
#   'co': 0.18},
#  {'site_name': '新港',
#   'county': '嘉義縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.1,
#   'co': 0.1},
#  {'site_name': '崙背',
#   'county': '雲林縣',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.0,
#   'co': 0.09},
#  {'site_name': '斗六',
#   'county': '雲林縣',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.5,
#   'co': 0.17},
#  {'site_name': '南投',
#   'county': '南投縣',
#   'aqi': 46,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.9,
#   'co': 0.13},
#  {'site_name': '二林',
#   'county': '彰化縣',
#   'aqi': 50,
#   'status': '良好',
#   'pm25': 18.0,
#   'so2': 1.3,
#   'co': 0.08},
#  {'site_name': '線西',
#   'county': '彰化縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.9,
#   'co': 0.08},
#  {'site_name': '彰化',
#   'county': '彰化縣',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.0,
#   'co': 0.1},
#  {'site_name': '西屯',
#   'county': '臺中市',
#   'aqi': 43,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.5,
#   'co': 0.09},
#  {'site_name': '忠明',
#   'county': '臺中市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.4,
#   'co': 0.19},
#  {'site_name': '大里',
#   'county': '臺中市',
#   'aqi': 43,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.3,
#   'co': 0.13},
#  {'site_name': '沙鹿',
#   'county': '臺中市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.7,
#   'co': 0.13},
#  {'site_name': '豐原',
#   'county': '臺中市',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.6,
#   'co': 0.16},
#  {'site_name': '三義',
#   'county': '苗栗縣',
#   'aqi': 49,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.5,
#   'co': 0.15},
#  {'site_name': '苗栗',
#   'county': '苗栗縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.2,
#   'co': 0.09},
#  {'site_name': '頭份',
#   'county': '苗栗縣',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.7,
#   'co': 0.12},
#  {'site_name': '新竹',
#   'county': '新竹市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.8,
#   'co': 0.14},
#  {'site_name': '竹東',
#   'county': '新竹縣',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.4,
#   'co': 0.12},
#  {'site_name': '湖口',
#   'county': '新竹縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.0,
#   'co': 0.1},
#  {'site_name': '龍潭',
#   'county': '桃園市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.2,
#   'co': 0.1},
#  {'site_name': '平鎮',
#   'county': '桃園市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.4,
#   'co': 0.11},
#  {'site_name': '觀音',
#   'county': '桃園市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.0,
#   'co': 0.06},
#  {'site_name': '大園',
#   'county': '桃園市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.2,
#   'co': 0.11},
#  {'site_name': '桃園',
#   'county': '桃園市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.5,
#   'co': 0.15},
#  {'site_name': '大同',
#   'county': '臺北市',
#   'aqi': 60,
#   'status': '普通',
#   'pm25': 17.0,
#   'so2': 0.9,
#   'co': 0.86},
#  {'site_name': '松山',
#   'county': '臺北市',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.35},
#  {'site_name': '古亭',
#   'county': '臺北市',
#   'aqi': 49,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.4,
#   'co': 0.21},
#  {'site_name': '萬華',
#   'county': '臺北市',
#   'aqi': 49,
#   'status': '良好',
#   'pm25': 18.0,
#   'so2': 0.8,
#   'co': 0.28},
#  {'site_name': '中山',
#   'county': '臺北市',
#   'aqi': 55,
#   'status': '普通',
#   'pm25': 15.0,
#   'so2': 1.2,
#   'co': 0.45},
#  {'site_name': '士林',
#   'county': '臺北市',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 18.0,
#   'so2': 0.9,
#   'co': 0.12},
#  {'site_name': '淡水',
#   'county': '新北市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.4,
#   'co': 0.11},
#  {'site_name': '林口',
#   'county': '新北市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.0,
#   'co': 0.12},
#  {'site_name': '菜寮',
#   'county': '新北市',
#   'aqi': 53,
#   'status': '普通',
#   'pm25': 15.0,
#   'so2': 1.3,
#   'co': 0.24},
#  {'site_name': '新莊',
#   'county': '新北市',
#   'aqi': 46,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.0,
#   'co': 0.12},
#  {'site_name': '板橋',
#   'county': '新北市',
#   'aqi': 43,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.1,
#   'co': 0.2},
#  {'site_name': '土城',
#   'county': '新北市',
#   'aqi': 67,
#   'status': '普通',
#   'pm25': 24.0,
#   'so2': 0.2,
#   'co': 0.17},
#  {'site_name': '新店',
#   'county': '新北市',
#   'aqi': 58,
#   'status': '普通',
#   'pm25': 22.0,
#   'so2': 0.9,
#   'co': 0.27},
#  {'site_name': '萬里',
#   'county': '新北市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.9,
#   'co': 0.18},
#  {'site_name': '汐止',
#   'county': '新北市',
#   'aqi': 56,
#   'status': '普通',
#   'pm25': 15.0,
#   'so2': 1.7,
#   'co': 0.27},
#  {'site_name': '基隆',
#   'county': '基隆市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.5,
#   'co': 0.23},
#  {'site_name': '屏東(枋山)',
#   'county': '屏東縣',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.5,
#   'co': 0.09},
#  {'site_name': '大甲（日南國小）',
#   'county': '臺中市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.7,
#   'co': 0.15},
#  {'site_name': '新北(樹林)',
#   'county': '新北市',
#   'aqi': 54,
#   'status': '普通',
#   'pm25': 18.0,
#   'so2': 0.9,
#   'co': 0.16},
#  {'site_name': '屏東（琉球）',
#   'county': '屏東縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.6,
#   'co': 0.12},
#  {'site_name': '臺南（麻豆）',
#   'county': '臺南市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '高雄（湖內）',
#   'county': '高雄市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.2,
#   'co': 0.1},
#  {'site_name': '彰化（員林）',
#   'county': '彰化縣',
#   'aqi': 46,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 2.0,
#   'co': 0.14},
#  {'site_name': '大城',
#   'county': '彰化縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.4,
#   'co': 0.03},
#  {'site_name': '富貴角',
#   'county': '新北市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.3,
#   'co': 0.07},
#  {'site_name': '麥寮',
#   'county': '雲林縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.2,
#   'co': 0.09},
#  {'site_name': '關山',
#   'county': '臺東縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.6,
#   'co': 0.08},
#  {'site_name': '馬公',
#   'county': '澎湖縣',
#   'aqi': 19,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.9,
#   'co': 0.14},
#  {'site_name': '金門',
#   'county': '金門縣',
#   'aqi': 19,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.4,
#   'co': 0.08},
#  {'site_name': '馬祖',
#   'county': '連江縣',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.3,
#   'co': 0.08},
#  {'site_name': '埔里',
#   'county': '南投縣',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 22.0,
#   'so2': 1.1,
#   'co': 0.2},
#  {'site_name': '復興',
#   'county': '高雄市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.6,
#   'co': 0.14},
#  {'site_name': '永和',
#   'county': '新北市',
#   'aqi': 59,
#   'status': '普通',
#   'pm25': 20.0,
#   'so2': 0.0,
#   'co': 0.5},
#  {'site_name': '竹山',
#   'county': '南投縣',
#   'aqi': 60,
#   'status': '普通',
#   'pm25': 21.0,
#   'so2': 1.2,
#   'co': 0.1},
#  {'site_name': '中壢',
#   'county': '桃園市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.8,
#   'co': 0.45},
#  {'site_name': '三重',
#   'county': '新北市',
#   'aqi': 58,
#   'status': '普通',
#   'pm25': 19.0,
#   'so2': 1.6,
#   'co': 1.06},
#  {'site_name': '冬山',
#   'county': '宜蘭縣',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.2,
#   'co': 0.48},
#  {'site_name': '宜蘭',
#   'county': '宜蘭縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.2,
#   'co': 0.31},
#  {'site_name': '陽明',
#   'county': '臺北市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.1,
#   'co': 0.15},
#  {'site_name': '花蓮',
#   'county': '花蓮縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 0.5,
#   'co': 0.12},
#  {'site_name': '臺東',
#   'county': '臺東縣',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.1,
#   'co': 0.13},
#  {'site_name': '恆春',
#   'county': '屏東縣',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.0,
#   'co': 0.09},
#  {'site_name': '潮州',
#   'county': '屏東縣',
#   'aqi': -1,
#   'status': '',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '屏東',
#   'county': '屏東縣',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.3,
#   'co': 0.13},
#  {'site_name': '小港',
#   'county': '高雄市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.6,
#   'co': 0.15},
#  {'site_name': '前鎮',
#   'county': '高雄市',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.2,
#   'co': 0.17},
#  {'site_name': '前金',
#   'county': '高雄市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '左營',
#   'county': '高雄市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.6,
#   'co': 0.11},
#  {'site_name': '楠梓',
#   'county': '高雄市',
#   'aqi': 43,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.9,
#   'co': 0.11},
#  {'site_name': '林園',
#   'county': '高雄市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.2,
#   'co': 0.1},
#  {'site_name': '大寮',
#   'county': '高雄市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.4,
#   'co': 0.12},
#  {'site_name': '鳳山',
#   'county': '高雄市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.9,
#   'co': 0.28},
#  {'site_name': '仁武',
#   'county': '高雄市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.2,
#   'co': 0.13},
#  {'site_name': '橋頭',
#   'county': '高雄市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.0,
#   'co': 0.08},
#  {'site_name': '美濃',
#   'county': '高雄市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 2.0,
#   'co': 0.16},
#  {'site_name': '臺南',
#   'county': '臺南市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.0,
#   'co': 0.1},
#  {'site_name': '安南',
#   'county': '臺南市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.5,
#   'co': 0.15},
#  {'site_name': '善化',
#   'county': '臺南市',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.1,
#   'co': 0.07},
#  {'site_name': '新營',
#   'county': '臺南市',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.4,
#   'co': 0.15},
#  {'site_name': '嘉義',
#   'county': '嘉義市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '臺西',
#   'county': '雲林縣',
#   'aqi': 48,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.5,
#   'co': 0.09},
#  {'site_name': '朴子',
#   'county': '嘉義縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '新港',
#   'county': '嘉義縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.7,
#   'co': 0.09},
#  {'site_name': '崙背',
#   'county': '雲林縣',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '斗六',
#   'county': '雲林縣',
#   'aqi': 46,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.7,
#   'co': 0.17},
#  {'site_name': '南投',
#   'county': '南投縣',
#   'aqi': 48,
#   'status': '良好',
#   'pm25': 20.0,
#   'so2': 0.9,
#   'co': 0.13},
#  {'site_name': '二林',
#   'county': '彰化縣',
#   'aqi': 48,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.5,
#   'co': 0.08},
#  {'site_name': '線西',
#   'county': '彰化縣',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.1,
#   'co': 0.08},
#  {'site_name': '彰化',
#   'county': '彰化縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '西屯',
#   'county': '臺中市',
#   'aqi': 43,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.5,
#   'co': 0.09},
#  {'site_name': '忠明',
#   'county': '臺中市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.3,
#   'co': 0.17},
#  {'site_name': '大里',
#   'county': '臺中市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.4,
#   'co': 0.11},
#  {'site_name': '沙鹿',
#   'county': '臺中市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.8,
#   'co': 0.12},
#  {'site_name': '豐原',
#   'county': '臺中市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.5,
#   'co': 0.16},
#  {'site_name': '三義',
#   'county': '苗栗縣',
#   'aqi': 51,
#   'status': '普通',
#   'pm25': 16.0,
#   'so2': 1.8,
#   'co': 0.15},
#  {'site_name': '苗栗',
#   'county': '苗栗縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.3,
#   'co': 0.07},
#  {'site_name': '頭份',
#   'county': '苗栗縣',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.6,
#   'co': 0.13},
#  {'site_name': '新竹',
#   'county': '新竹市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.9,
#   'co': 0.13},
#  {'site_name': '竹東',
#   'county': '新竹縣',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.5,
#   'co': 0.12},
#  {'site_name': '湖口',
#   'county': '新竹縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.2,
#   'co': 0.09},
#  {'site_name': '龍潭',
#   'county': '桃園市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.0,
#   'co': 0.1},
#  {'site_name': '平鎮',
#   'county': '桃園市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.3,
#   'co': 0.11},
#  {'site_name': '觀音',
#   'county': '桃園市',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '大園',
#   'county': '桃園市',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '桃園',
#   'county': '桃園市',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 1.5,
#   'co': 0.14},
#  {'site_name': '大同',
#   'county': '臺北市',
#   'aqi': 63,
#   'status': '普通',
#   'pm25': 18.0,
#   'so2': 1.0,
#   'co': 0.78},
#  {'site_name': '松山',
#   'county': '臺北市',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 19.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '古亭',
#   'county': '臺北市',
#   'aqi': 52,
#   'status': '普通',
#   'pm25': 19.0,
#   'so2': 1.5,
#   'co': 0.23},
#  {'site_name': '萬華',
#   'county': '臺北市',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '中山',
#   'county': '臺北市',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 19.0,
#   'so2': 1.3,
#   'co': 0.49},
#  {'site_name': '士林',
#   'county': '臺北市',
#   'aqi': 55,
#   'status': '普通',
#   'pm25': 20.0,
#   'so2': 1.0,
#   'co': 0.14},
#  {'site_name': '淡水',
#   'county': '新北市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.5,
#   'co': 0.11},
#  {'site_name': '林口',
#   'county': '新北市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.0,
#   'co': 0.13},
#  {'site_name': '菜寮',
#   'county': '新北市',
#   'aqi': 53,
#   'status': '普通',
#   'pm25': 12.0,
#   'so2': 1.5,
#   'co': 0.23},
#  {'site_name': '新莊',
#   'county': '新北市',
#   'aqi': 48,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.0,
#   'co': 0.13},
#  {'site_name': '板橋',
#   'county': '新北市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.2,
#   'co': 0.19},
#  {'site_name': '土城',
#   'county': '新北市',
#   'aqi': 67,
#   'status': '普通',
#   'pm25': 20.0,
#   'so2': 0.6,
#   'co': 0.18},
#  {'site_name': '新店',
#   'county': '新北市',
#   'aqi': 56,
#   'status': '普通',
#   'pm25': 20.0,
#   'so2': 1.5,
#   'co': 0.23},
#  {'site_name': '萬里',
#   'county': '新北市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.9,
#   'co': 0.18},
#  {'site_name': '汐止',
#   'county': '新北市',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 17.0,
#   'so2': 1.2,
#   'co': 0.25},
#  {'site_name': '基隆',
#   'county': '基隆市',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.8,
#   'co': 0.19},
#  {'site_name': '屏東(枋山)',
#   'county': '屏東縣',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.5,
#   'co': 0.09},
#  {'site_name': '大甲（日南國小）',
#   'county': '臺中市',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '新北(樹林)',
#   'county': '新北市',
#   'aqi': 51,
#   'status': '普通',
#   'pm25': 23.0,
#   'so2': 1.3,
#   'co': 0.19},
#  {'site_name': '屏東（琉球）',
#   'county': '屏東縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.7,
#   'co': 0.1},
#  {'site_name': '臺南（麻豆）',
#   'county': '臺南市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '高雄（湖內）',
#   'county': '高雄市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '彰化（員林）',
#   'county': '彰化縣',
#   'aqi': 46,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 2.0,
#   'co': 0.15},
#  {'site_name': '大城',
#   'county': '彰化縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.4,
#   'co': 0.03},
#  {'site_name': '富貴角',
#   'county': '新北市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.4,
#   'co': 0.07},
#  {'site_name': '麥寮',
#   'county': '雲林縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.2,
#   'co': 0.08},
#  {'site_name': '關山',
#   'county': '臺東縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.5,
#   'co': 0.08},
#  {'site_name': '馬公',
#   'county': '澎湖縣',
#   'aqi': 18,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.8,
#   'co': 0.16},
#  {'site_name': '金門',
#   'county': '金門縣',
#   'aqi': 19,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.3,
#   'co': 0.07},
#  {'site_name': '馬祖',
#   'county': '連江縣',
#   'aqi': 21,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.3,
#   'co': 0.08},
#  {'site_name': '埔里',
#   'county': '南投縣',
#   'aqi': 52,
#   'status': '普通',
#   'pm25': 24.0,
#   'so2': 1.4,
#   'co': 0.18},
#  {'site_name': '復興',
#   'county': '高雄市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.4,
#   'co': 0.12},
#  {'site_name': '永和',
#   'county': '新北市',
#   'aqi': 56,
#   'status': '普通',
#   'pm25': 20.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '竹山',
#   'county': '南投縣',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 19.0,
#   'so2': 1.4,
#   'co': 0.11},
#  {'site_name': '中壢',
#   'county': '桃園市',
#   'aqi': 48,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.6,
#   'co': 0.38},
#  {'site_name': '三重',
#   'county': '新北市',
#   'aqi': 58,
#   'status': '普通',
#   'pm25': 22.0,
#   'so2': 1.8,
#   'co': 0.96},
#  {'site_name': '冬山',
#   'county': '宜蘭縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.9,
#   'co': 0.51},
#  {'site_name': '宜蘭',
#   'county': '宜蘭縣',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 18.0,
#   'so2': 1.2,
#   'co': 0.29},
#  {'site_name': '陽明',
#   'county': '臺北市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.4,
#   'co': 0.16},
#  {'site_name': '花蓮',
#   'county': '花蓮縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.6,
#   'co': 0.14},
#  {'site_name': '臺東',
#   'county': '臺東縣',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.3,
#   'co': 0.13},
#  {'site_name': '恆春',
#   'county': '屏東縣',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.0,
#   'co': 0.09},
#  {'site_name': '潮州',
#   'county': '屏東縣',
#   'aqi': -1,
#   'status': '',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '屏東',
#   'county': '屏東縣',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.0,
#   'co': 0.13},
#  {'site_name': '小港',
#   'county': '高雄市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.9,
#   'co': 0.13},
#  {'site_name': '前鎮',
#   'county': '高雄市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.8,
#   'co': 0.16},
#  {'site_name': '前金',
#   'county': '高雄市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.3,
#   'co': 0.11},
#  {'site_name': '左營',
#   'county': '高雄市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 0.4,
#   'co': 0.1},
#  {'site_name': '楠梓',
#   'county': '高雄市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.1,
#   'co': 0.11},
#  {'site_name': '林園',
#   'county': '高雄市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.3,
#   'co': 0.09},
#  {'site_name': '大寮',
#   'county': '高雄市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.4,
#   'co': 0.15},
#  {'site_name': '鳳山',
#   'county': '高雄市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 1.5,
#   'co': 0.22},
#  {'site_name': '仁武',
#   'county': '高雄市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.9,
#   'co': 0.15},
#  {'site_name': '橋頭',
#   'county': '高雄市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.0,
#   'co': 0.08},
#  {'site_name': '美濃',
#   'county': '高雄市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 2.2,
#   'co': 0.14},
#  {'site_name': '臺南',
#   'county': '臺南市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.3,
#   'co': 0.1},
#  {'site_name': '安南',
#   'county': '臺南市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.5,
#   'co': 0.14},
#  {'site_name': '善化',
#   'county': '臺南市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.8,
#   'co': 0.08},
#  {'site_name': '新營',
#   'county': '臺南市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.4,
#   'co': 0.15},
#  {'site_name': '嘉義',
#   'county': '嘉義市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 1.6,
#   'co': 0.15},
#  {'site_name': '臺西',
#   'county': '雲林縣',
#   'aqi': 46,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.6,
#   'co': 0.09},
#  {'site_name': '朴子',
#   'county': '嘉義縣',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.2,
#   'co': 0.09},
#  {'site_name': '新港',
#   'county': '嘉義縣',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.5,
#   'co': 0.1},
#  {'site_name': '崙背',
#   'county': '雲林縣',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '斗六',
#   'county': '雲林縣',
#   'aqi': 48,
#   'status': '良好',
#   'pm25': 19.0,
#   'so2': 1.7,
#   'co': 0.17},
#  {'site_name': '南投',
#   'county': '南投縣',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.8,
#   'co': 0.13},
#  {'site_name': '二林',
#   'county': '彰化縣',
#   'aqi': 46,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.6,
#   'co': 0.08},
#  {'site_name': '線西',
#   'county': '彰化縣',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.3,
#   'co': 0.08},
#  {'site_name': '彰化',
#   'county': '彰化縣',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 1.0,
#   'co': 0.08},
#  {'site_name': '西屯',
#   'county': '臺中市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.3,
#   'co': 0.1},
#  {'site_name': '忠明',
#   'county': '臺中市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.5,
#   'co': 0.16},
#  {'site_name': '大里',
#   'county': '臺中市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.3,
#   'co': 0.12},
#  {'site_name': '沙鹿',
#   'county': '臺中市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 2.0,
#   'co': 0.13},
#  {'site_name': '豐原',
#   'county': '臺中市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 18.0,
#   'so2': 1.4,
#   'co': 0.16},
#  {'site_name': '三義',
#   'county': '苗栗縣',
#   'aqi': 50,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.4,
#   'co': 0.14},
#  {'site_name': '苗栗',
#   'county': '苗栗縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '頭份',
#   'county': '苗栗縣',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.7,
#   'co': 0.12},
#  {'site_name': '新竹',
#   'county': '新竹市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.9,
#   'co': 0.13},
#  {'site_name': '竹東',
#   'county': '新竹縣',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.6,
#   'co': 0.12},
#  {'site_name': '湖口',
#   'county': '新竹縣',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.2,
#   'co': 0.1},
#  {'site_name': '龍潭',
#   'county': '桃園市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.2,
#   'co': 0.11},
#  {'site_name': '平鎮',
#   'county': '桃園市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.4,
#   'co': 0.11},
#  {'site_name': '觀音',
#   'county': '桃園市',
#   'aqi': 21,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.0,
#   'co': 0.05},
#  {'site_name': '大園',
#   'county': '桃園市',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.9,
#   'co': 0.11},
#  {'site_name': '桃園',
#   'county': '桃園市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.7,
#   'co': 0.16},
#  {'site_name': '大同',
#   'county': '臺北市',
#   'aqi': 63,
#   'status': '普通',
#   'pm25': 21.0,
#   'so2': 1.3,
#   'co': 0.81},
#  {'site_name': '松山',
#   'county': '臺北市',
#   'aqi': 54,
#   'status': '普通',
#   'pm25': 20.0,
#   'so2': 1.1,
#   'co': 0.28},
#  {'site_name': '古亭',
#   'county': '臺北市',
#   'aqi': 49,
#   'status': '良好',
#   'pm25': 20.0,
#   'so2': 1.7,
#   'co': 0.26},
#  {'site_name': '萬華',
#   'county': '臺北市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.1,
#   'co': 0.31},
#  {'site_name': '中山',
#   'county': '臺北市',
#   'aqi': 57,
#   'status': '普通',
#   'pm25': 19.0,
#   'so2': 1.5,
#   'co': 0.4},
#  {'site_name': '士林',
#   'county': '臺北市',
#   'aqi': 52,
#   'status': '普通',
#   'pm25': 19.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '淡水',
#   'county': '新北市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.4,
#   'co': 0.12},
#  {'site_name': '林口',
#   'county': '新北市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.4,
#   'co': 0.17},
#  {'site_name': '菜寮',
#   'county': '新北市',
#   'aqi': 55,
#   'status': '普通',
#   'pm25': 21.0,
#   'so2': 1.8,
#   'co': 0.25},
#  {'site_name': '新莊',
#   'county': '新北市',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.3,
#   'co': 0.15},
#  {'site_name': '板橋',
#   'county': '新北市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.0,
#   'co': 0.23},
#  {'site_name': '土城',
#   'county': '新北市',
#   'aqi': 68,
#   'status': '普通',
#   'pm25': 23.0,
#   'so2': 0.9,
#   'co': 0.22},
#  {'site_name': '新店',
#   'county': '新北市',
#   'aqi': 53,
#   'status': '普通',
#   'pm25': 22.0,
#   'so2': 1.4,
#   'co': 0.23},
#  {'site_name': '萬里',
#   'county': '新北市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.9,
#   'co': 0.15},
#  {'site_name': '汐止',
#   'county': '新北市',
#   'aqi': 55,
#   'status': '普通',
#   'pm25': 22.0,
#   'so2': 0.5,
#   'co': 0.31},
#  {'site_name': '基隆',
#   'county': '基隆市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.8,
#   'co': 0.18},
#  {'site_name': '屏東(枋山)',
#   'county': '屏東縣',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.5,
#   'co': 0.11},
#  {'site_name': '大甲（日南國小）',
#   'county': '臺中市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '新北(樹林)',
#   'county': '新北市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 20.0,
#   'so2': 1.6,
#   'co': 0.23},
#  {'site_name': '屏東（琉球）',
#   'county': '屏東縣',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.8,
#   'co': 0.1},
#  {'site_name': '臺南（麻豆）',
#   'county': '臺南市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '高雄（湖內）',
#   'county': '高雄市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.0,
#   'co': 0.09},
#  {'site_name': '彰化（員林）',
#   'county': '彰化縣',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 2.1,
#   'co': 0.15},
#  {'site_name': '大城',
#   'county': '彰化縣',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.5,
#   'co': 0.03},
#  {'site_name': '富貴角',
#   'county': '新北市',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.6,
#   'co': 0.09},
#  {'site_name': '麥寮',
#   'county': '雲林縣',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.2,
#   'co': 0.08},
#  {'site_name': '關山',
#   'county': '臺東縣',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.5,
#   'co': 0.08},
#  {'site_name': '馬公',
#   'county': '澎湖縣',
#   'aqi': 19,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.9,
#   'co': 0.16},
#  {'site_name': '金門',
#   'county': '金門縣',
#   'aqi': 17,
#   'status': '良好',
#   'pm25': 4.0,
#   'so2': 1.2,
#   'co': 0.07},
#  {'site_name': '馬祖',
#   'county': '連江縣',
#   'aqi': 20,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.4,
#   'co': 0.08},
#  {'site_name': '埔里',
#   'county': '南投縣',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.4,
#   'co': 0.15},
#  {'site_name': '復興',
#   'county': '高雄市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.5,
#   'co': 0.12},
#  {'site_name': '永和',
#   'county': '新北市',
#   'aqi': 55,
#   'status': '普通',
#   'pm25': 25.0,
#   'so2': 1.3,
#   'co': 0.69},
#  {'site_name': '竹山',
#   'county': '南投縣',
#   'aqi': 56,
#   'status': '普通',
#   'pm25': 26.0,
#   'so2': 2.3,
#   'co': 0.19},
#  {'site_name': '中壢',
#   'county': '桃園市',
#   'aqi': 49,
#   'status': '良好',
#   'pm25': 19.0,
#   'so2': 1.1,
#   'co': 0.44},
#  {'site_name': '三重',
#   'county': '新北市',
#   'aqi': 58,
#   'status': '普通',
#   'pm25': 20.0,
#   'so2': 1.5,
#   'co': 0.87},
#  {'site_name': '冬山',
#   'county': '宜蘭縣',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 18.0,
#   'so2': 1.3,
#   'co': 0.61},
#  {'site_name': '宜蘭',
#   'county': '宜蘭縣',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.2,
#   'co': 0.21},
#  {'site_name': '陽明',
#   'county': '臺北市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.5,
#   'co': 0.24},
#  {'site_name': '花蓮',
#   'county': '花蓮縣',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 19.0,
#   'so2': 0.9,
#   'co': 0.17},
#  {'site_name': '臺東',
#   'county': '臺東縣',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.2,
#   'co': 0.12},
#  {'site_name': '恆春',
#   'county': '屏東縣',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.0,
#   'co': 0.09},
#  {'site_name': '潮州',
#   'county': '屏東縣',
#   'aqi': -1,
#   'status': '',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '屏東',
#   'county': '屏東縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.0,
#   'co': 0.13},
#  {'site_name': '小港',
#   'county': '高雄市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.0,
#   'co': 0.12},
#  {'site_name': '前鎮',
#   'county': '高雄市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.9,
#   'co': 0.1},
#  {'site_name': '前金',
#   'county': '高雄市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.5,
#   'co': 0.11},
#  {'site_name': '左營',
#   'county': '高雄市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.6,
#   'co': 0.11},
#  {'site_name': '楠梓',
#   'county': '高雄市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.1,
#   'co': 0.11},
#  {'site_name': '林園',
#   'county': '高雄市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.3,
#   'co': 0.09},
#  {'site_name': '大寮',
#   'county': '高雄市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.4,
#   'co': 0.11},
#  {'site_name': '鳳山',
#   'county': '高雄市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.9,
#   'co': 0.27},
#  {'site_name': '仁武',
#   'county': '高雄市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.9,
#   'co': 0.12},
#  {'site_name': '橋頭',
#   'county': '高雄市',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.1,
#   'co': 0.08},
#  {'site_name': '美濃',
#   'county': '高雄市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 2.0,
#   'co': 0.12},
#  {'site_name': '臺南',
#   'county': '臺南市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.4,
#   'co': 0.09},
#  {'site_name': '安南',
#   'county': '臺南市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.5,
#   'co': 0.14},
#  {'site_name': '善化',
#   'county': '臺南市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.2,
#   'co': 0.07},
#  {'site_name': '新營',
#   'county': '臺南市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.5,
#   'co': 0.23},
#  {'site_name': '嘉義',
#   'county': '嘉義市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.6,
#   'co': 0.16},
#  {'site_name': '臺西',
#   'county': '雲林縣',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.6,
#   'co': 0.08},
#  {'site_name': '朴子',
#   'county': '嘉義縣',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.0,
#   'co': 0.08},
#  {'site_name': '新港',
#   'county': '嘉義縣',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '崙背',
#   'county': '雲林縣',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 0.0,
#   'so2': 0.9,
#   'co': 0.09},
#  {'site_name': '斗六',
#   'county': '雲林縣',
#   'aqi': 43,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.7,
#   'co': 0.18},
#  {'site_name': '南投',
#   'county': '南投縣',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.2,
#   'co': 0.14},
#  {'site_name': '二林',
#   'county': '彰化縣',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.5,
#   'co': 0.08},
#  {'site_name': '線西',
#   'county': '彰化縣',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.5,
#   'co': 0.08},
#  {'site_name': '彰化',
#   'county': '彰化縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.1,
#   'co': 0.07},
#  {'site_name': '西屯',
#   'county': '臺中市',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.3,
#   'co': 0.11},
#  {'site_name': '忠明',
#   'county': '臺中市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.6,
#   'co': 0.16},
#  {'site_name': '大里',
#   'county': '臺中市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.5,
#   'co': 0.11},
#  {'site_name': '沙鹿',
#   'county': '臺中市',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.8,
#   'co': 0.13},
#  {'site_name': '豐原',
#   'county': '臺中市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.6,
#   'co': 0.15},
#  {'site_name': '三義',
#   'county': '苗栗縣',
#   'aqi': 49,
#   'status': '良好',
#   'pm25': 19.0,
#   'so2': 1.7,
#   'co': 0.14},
#  {'site_name': '苗栗',
#   'county': '苗栗縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.8,
#   'co': 0.1},
#  {'site_name': '頭份',
#   'county': '苗栗縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.0,
#   'co': 0.11},
#  {'site_name': '新竹',
#   'county': '新竹市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.9,
#   'co': 0.13},
#  {'site_name': '竹東',
#   'county': '新竹縣',
#   'aqi': 47,
#   'status': '良好',
#   'pm25': 18.0,
#   'so2': 1.3,
#   'co': 0.17},
#  {'site_name': '湖口',
#   'county': '新竹縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.4,
#   'co': 0.14},
#  {'site_name': '龍潭',
#   'county': '桃園市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.8,
#   'co': 0.15},
#  {'site_name': '平鎮',
#   'county': '桃園市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.6,
#   'co': 0.12},
#  {'site_name': '觀音',
#   'county': '桃園市',
#   'aqi': 20,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.0,
#   'co': 0.04},
#  {'site_name': '大園',
#   'county': '桃園市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.0,
#   'co': 0.11},
#  {'site_name': '桃園',
#   'county': '桃園市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.7,
#   'co': 0.17},
#  {'site_name': '大同',
#   'county': '臺北市',
#   'aqi': 63,
#   'status': '普通',
#   'pm25': 25.0,
#   'so2': 0.0,
#   'co': 0.0},
#  {'site_name': '松山',
#   'county': '臺北市',
#   'aqi': 52,
#   'status': '普通',
#   'pm25': 21.0,
#   'so2': 1.1,
#   'co': 0.36},
#  {'site_name': '古亭',
#   'county': '臺北市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 20.0,
#   'so2': 1.4,
#   'co': 0.32},
#  {'site_name': '萬華',
#   'county': '臺北市',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 19.0,
#   'so2': 1.2,
#   'co': 0.42},
#  {'site_name': '中山',
#   'county': '臺北市',
#   'aqi': 54,
#   'status': '普通',
#   'pm25': 21.0,
#   'so2': 1.4,
#   'co': 0.42},
#  {'site_name': '士林',
# ...
#   'pm25': 3.0,
#   'so2': 0.9,
#   'co': 0.14},
#  {'site_name': '金門',
#   'county': '金門縣',
#   'aqi': 13,
#   'status': '良好',
#   'pm25': 4.0,
#   'so2': 0.9,
#   'co': 0.09},
#  {'site_name': '馬祖',
#   'county': '連江縣',
#   'aqi': 16,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.4,
#   'co': 0.08},
#  {'site_name': '埔里',
#   'county': '南投縣',
#   'aqi': 51,
#   'status': '普通',
#   'pm25': 14.0,
#   'so2': 1.0,
#   'co': 0.25},
#  {'site_name': '復興',
#   'county': '高雄市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 2.0,
#   'co': 0.51},
#  {'site_name': '永和',
#   'county': '新北市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.0,
#   'co': 0.87},
#  {'site_name': '竹山',
#   'county': '南投縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.6,
#   'co': 0.17},
#  {'site_name': '中壢',
#   'county': '桃園市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.2,
#   'co': 1.7},
#  {'site_name': '三重',
#   'county': '新北市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.1,
#   'co': 1.31},
#  {'site_name': '冬山',
#   'county': '宜蘭縣',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.7,
#   'co': 0.28},
#  {'site_name': '宜蘭',
#   'county': '宜蘭縣',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.0,
#   'co': 0.24},
#  {'site_name': '陽明',
#   'county': '臺北市',
#   'aqi': 19,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 1.1,
#   'co': 0.11},
#  {'site_name': '花蓮',
#   'county': '花蓮縣',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.8,
#   'co': 0.26},
#  {'site_name': '臺東',
#   'county': '臺東縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.1,
#   'co': 0.14},
#  {'site_name': '恆春',
#   'county': '屏東縣',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.9,
#   'co': 0.08},
#  {'site_name': '潮州',
#   'county': '屏東縣',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.7,
#   'co': 0.19},
#  {'site_name': '屏東',
#   'county': '屏東縣',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.0,
#   'co': 0.3},
#  {'site_name': '小港',
#   'county': '高雄市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 2.5,
#   'co': 0.47},
#  {'site_name': '前鎮',
#   'county': '高雄市',
#   'aqi': 27,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.7,
#   'co': 0.54},
#  {'site_name': '前金',
#   'county': '高雄市',
#   'aqi': 27,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 3.2,
#   'co': 0.25},
#  {'site_name': '左營',
#   'county': '高雄市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.6,
#   'co': 0.34},
#  {'site_name': '楠梓',
#   'county': '高雄市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 19.0,
#   'so2': 2.7,
#   'co': 0.43},
#  {'site_name': '林園',
#   'county': '高雄市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.1,
#   'co': 0.17},
#  {'site_name': '大寮',
#   'county': '高雄市',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.4,
#   'co': 0.25},
#  {'site_name': '鳳山',
#   'county': '高雄市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.3,
#   'co': 0.57},
#  {'site_name': '仁武',
#   'county': '高雄市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.3,
#   'co': 0.35},
#  {'site_name': '橋頭',
#   'county': '高雄市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 20.0,
#   'so2': 2.1,
#   'co': 0.36},
#  {'site_name': '美濃',
#   'county': '高雄市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.0,
#   'co': 0.2},
#  {'site_name': '臺南',
#   'county': '臺南市',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.8,
#   'co': 0.38},
#  {'site_name': '安南',
#   'county': '臺南市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 2.0,
#   'co': 0.47},
#  {'site_name': '善化',
#   'county': '臺南市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.1,
#   'co': 0.23},
#  {'site_name': '新營',
#   'county': '臺南市',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.8,
#   'co': 0.34},
#  {'site_name': '嘉義',
#   'county': '嘉義市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.5,
#   'co': 0.22},
#  {'site_name': '臺西',
#   'county': '雲林縣',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 1.7,
#   'co': 0.2},
#  {'site_name': '朴子',
#   'county': '嘉義縣',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 2.6,
#   'co': 0.35},
#  {'site_name': '新港',
#   'county': '嘉義縣',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 2.6,
#   'co': 0.26},
#  {'site_name': '崙背',
#   'county': '雲林縣',
#   'aqi': 45,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 1.8,
#   'co': 0.17},
#  {'site_name': '斗六',
#   'county': '雲林縣',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 1.5,
#   'co': 0.18},
#  {'site_name': '南投',
#   'county': '南投縣',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.5,
#   'co': 0.17},
#  {'site_name': '二林',
#   'county': '彰化縣',
#   'aqi': 43,
#   'status': '良好',
#   'pm25': 20.0,
#   'so2': 1.8,
#   'co': 0.2},
#  {'site_name': '線西',
#   'county': '彰化縣',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.5,
#   'co': 0.24},
#  {'site_name': '彰化',
#   'county': '彰化縣',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 2.3,
#   'co': 0.2},
#  {'site_name': '西屯',
#   'county': '臺中市',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.2,
#   'co': 0.24},
#  {'site_name': '忠明',
#   'county': '臺中市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.3,
#   'co': 0.3},
#  {'site_name': '大里',
#   'county': '臺中市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.9,
#   'co': 0.29},
#  {'site_name': '沙鹿',
#   'county': '臺中市',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.2,
#   'co': 0.33},
#  {'site_name': '豐原',
#   'county': '臺中市',
#   'aqi': 21,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.9,
#   'co': 0.26},
#  {'site_name': '三義',
#   'county': '苗栗縣',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.1,
#   'co': 0.15},
#  {'site_name': '苗栗',
#   'county': '苗栗縣',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.4,
#   'co': 0.11},
#  {'site_name': '頭份',
#   'county': '苗栗縣',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.5,
#   'co': 0.33},
#  {'site_name': '新竹',
#   'county': '新竹市',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.9,
#   'co': 0.35},
#  {'site_name': '竹東',
#   'county': '新竹縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.2,
#   'co': 0.21},
#  {'site_name': '湖口',
#   'county': '新竹縣',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.4,
#   'co': 0.22},
#  {'site_name': '龍潭',
#   'county': '桃園市',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.8,
#   'co': 0.22},
#  {'site_name': '平鎮',
#   'county': '桃園市',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.5,
#   'co': 0.42},
#  {'site_name': '觀音',
#   'county': '桃園市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.7,
#   'co': 0.24},
#  {'site_name': '大園',
#   'county': '桃園市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.8,
#   'co': 0.33},
#  {'site_name': '桃園',
#   'county': '桃園市',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 2.8,
#   'co': 0.52},
#  {'site_name': '大同',
#   'county': '臺北市',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 1.0,
#   'co': 1.91},
#  {'site_name': '松山',
#   'county': '臺北市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.3,
#   'co': 0.4},
#  {'site_name': '古亭',
#   'county': '臺北市',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.6,
#   'co': 0.34},
#  {'site_name': '萬華',
#   'county': '臺北市',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.4,
#   'co': 0.4},
#  {'site_name': '中山',
#   'county': '臺北市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.7,
#   'co': 0.44},
#  {'site_name': '士林',
#   'county': '臺北市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.3,
#   'co': 0.36},
#  {'site_name': '淡水',
#   'county': '新北市',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.7,
#   'co': 0.3},
#  {'site_name': '林口',
#   'county': '新北市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.1,
#   'co': 0.36},
#  {'site_name': '菜寮',
#   'county': '新北市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.7,
#   'co': 0.57},
#  {'site_name': '新莊',
#   'county': '新北市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.1,
#   'co': 0.46},
#  {'site_name': '板橋',
#   'county': '新北市',
#   'aqi': 18,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.6,
#   'co': 0.51},
#  {'site_name': '土城',
#   'county': '新北市',
#   'aqi': 54,
#   'status': '普通',
#   'pm25': 21.0,
#   'so2': 0.0,
#   'co': 0.57},
#  {'site_name': '新店',
#   'county': '新北市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.4,
#   'co': 0.32},
#  {'site_name': '萬里',
#   'county': '新北市',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.2,
#   'co': 0.16},
#  {'site_name': '汐止',
#   'county': '新北市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.4,
#   'co': 0.39},
#  {'site_name': '基隆',
#   'county': '基隆市',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.6,
#   'co': 0.37},
#  {'site_name': '屏東(枋山)',
#   'county': '屏東縣',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.4,
#   'co': 0.2},
#  {'site_name': '大甲（日南國小）',
#   'county': '臺中市',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.5,
#   'co': 0.15},
#  {'site_name': '新北(樹林)',
#   'county': '新北市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.5,
#   'co': 0.27},
#  {'site_name': '屏東（琉球）',
#   'county': '屏東縣',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.9,
#   'co': 0.1},
#  {'site_name': '臺南（麻豆）',
#   'county': '臺南市',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.7,
#   'co': 0.26},
#  {'site_name': '高雄（湖內）',
#   'county': '高雄市',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.3,
#   'co': 0.3},
#  {'site_name': '彰化（員林）',
#   'county': '彰化縣',
#   'aqi': 39,
#   'status': '良好',
#   'pm25': 18.0,
#   'so2': 1.5,
#   'co': 0.17},
#  {'site_name': '大城',
#   'county': '彰化縣',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.5,
#   'co': 0.14},
#  {'site_name': '富貴角',
#   'county': '新北市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.4,
#   'co': 0.12},
#  {'site_name': '麥寮',
#   'county': '雲林縣',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.5,
#   'co': 0.28},
#  {'site_name': '關山',
#   'county': '臺東縣',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.4,
#   'co': 0.12},
#  {'site_name': '馬公',
#   'county': '澎湖縣',
#   'aqi': 20,
#   'status': '良好',
#   'pm25': 1.0,
#   'so2': 0.9,
#   'co': 0.11},
#  {'site_name': '金門',
#   'county': '金門縣',
#   'aqi': 13,
#   'status': '良好',
#   'pm25': 3.0,
#   'so2': 0.8,
#   'co': 0.0},
#  {'site_name': '馬祖',
#   'county': '連江縣',
#   'aqi': 16,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.4,
#   'co': 0.08},
#  {'site_name': '埔里',
#   'county': '南投縣',
#   'aqi': 49,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.9,
#   'co': 0.21},
#  {'site_name': '復興',
#   'county': '高雄市',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.1,
#   'co': 0.34},
#  {'site_name': '永和',
#   'county': '新北市',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.0,
#   'co': 0.39},
#  {'site_name': '竹山',
#   'county': '南投縣',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.5,
#   'co': 0.13},
#  {'site_name': '中壢',
#   'county': '桃園市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.5,
#   'co': 1.18},
#  {'site_name': '三重',
#   'county': '新北市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.9,
#   'co': 0.83},
#  {'site_name': '冬山',
#   'county': '宜蘭縣',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.5,
#   'co': 0.35},
#  {'site_name': '宜蘭',
#   'county': '宜蘭縣',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.0,
#   'co': 0.19},
#  {'site_name': '陽明',
#   'county': '臺北市',
#   'aqi': 19,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.0,
#   'co': 0.11},
#  {'site_name': '花蓮',
#   'county': '花蓮縣',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.7,
#   'co': 0.21},
#  {'site_name': '臺東',
#   'county': '臺東縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 1.3,
#   'co': 0.12},
#  {'site_name': '恆春',
#   'county': '屏東縣',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 5.0,
#   'so2': 0.7,
#   'co': 0.09},
#  {'site_name': '潮州',
#   'county': '屏東縣',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 0.5,
#   'co': 0.16},
#  {'site_name': '屏東',
#   'county': '屏東縣',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 11.0,
#   'so2': 0.8,
#   'co': 0.15},
#  {'site_name': '小港',
#   'county': '高雄市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 0.4,
#   'co': 0.23},
#  {'site_name': '前鎮',
#   'county': '高雄市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.7,
#   'co': 0.39},
#  {'site_name': '前金',
#   'county': '高雄市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 1.4,
#   'co': 0.19},
#  {'site_name': '左營',
#   'county': '高雄市',
#   'aqi': 38,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.4,
#   'co': 0.22},
#  {'site_name': '楠梓',
#   'county': '高雄市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.1,
#   'co': 0.24},
#  {'site_name': '林園',
#   'county': '高雄市',
#   'aqi': 35,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.7,
#   'co': 0.17},
#  {'site_name': '大寮',
#   'county': '高雄市',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 0.7,
#   'co': 0.27},
#  {'site_name': '鳳山',
#   'county': '高雄市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.7,
#   'co': 0.28},
#  {'site_name': '仁武',
#   'county': '高雄市',
#   'aqi': 34,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.3,
#   'co': 0.2},
#  {'site_name': '橋頭',
#   'county': '高雄市',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 1.2,
#   'co': 0.19},
#  {'site_name': '美濃',
#   'county': '高雄市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.1,
#   'co': 0.19},
#  {'site_name': '臺南',
#   'county': '臺南市',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 0.9,
#   'co': 0.21},
#  {'site_name': '安南',
#   'county': '臺南市',
#   'aqi': 37,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 1.8,
#   'co': 0.31},
#  {'site_name': '善化',
#   'county': '臺南市',
#   'aqi': 33,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 0.8,
#   'co': 0.15},
#  {'site_name': '新營',
#   'county': '臺南市',
#   'aqi': 24,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.2,
#   'co': 0.21},
#  {'site_name': '嘉義',
#   'county': '嘉義市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 2.0,
#   'co': 0.15},
#  {'site_name': '臺西',
#   'county': '雲林縣',
#   'aqi': 23,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.3,
#   'co': 0.22},
#  {'site_name': '朴子',
#   'county': '嘉義縣',
#   'aqi': 36,
#   'status': '良好',
#   'pm25': 17.0,
#   'so2': 2.1,
#   'co': 0.26},
#  {'site_name': '新港',
#   'county': '嘉義縣',
#   'aqi': 41,
#   'status': '良好',
#   'pm25': 14.0,
#   'so2': 2.1,
#   'co': 0.24},
#  {'site_name': '崙背',
#   'county': '雲林縣',
#   'aqi': 42,
#   'status': '良好',
#   'pm25': 13.0,
#   'so2': 1.2,
#   'co': 0.25},
#  {'site_name': '斗六',
#   'county': '雲林縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 1.7,
#   'co': 0.22},
#  {'site_name': '南投',
#   'county': '南投縣',
#   'aqi': 29,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 0.5,
#   'co': 0.15},
#  {'site_name': '二林',
#   'county': '彰化縣',
#   'aqi': 40,
#   'status': '良好',
#   'pm25': 15.0,
#   'so2': 1.8,
#   'co': 0.18},
#  {'site_name': '線西',
#   'county': '彰化縣',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.2,
#   'co': 0.19},
#  {'site_name': '彰化',
#   'county': '彰化縣',
#   'aqi': 21,
#   'status': '良好',
#   'pm25': 10.0,
#   'so2': 2.9,
#   'co': 0.19},
#  {'site_name': '西屯',
#   'county': '臺中市',
#   'aqi': 30,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 1.0,
#   'co': 0.19},
#  {'site_name': '忠明',
#   'county': '臺中市',
#   'aqi': 28,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.1,
#   'co': 0.19},
#  {'site_name': '大里',
#   'county': '臺中市',
#   'aqi': 26,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.9,
#   'co': 0.25},
#  {'site_name': '沙鹿',
#   'county': '臺中市',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 12.0,
#   'so2': 1.6,
#   'co': 0.21},
#  {'site_name': '豐原',
#   'county': '臺中市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.7,
#   'co': 0.16},
#  {'site_name': '三義',
#   'county': '苗栗縣',
#   'aqi': 27,
#   'status': '良好',
#   'pm25': 6.0,
#   'so2': 1.2,
#   'co': 0.12},
#  {'site_name': '苗栗',
#   'county': '苗栗縣',
#   'aqi': 32,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.4,
#   'co': 0.12},
#  {'site_name': '頭份',
#   'county': '苗栗縣',
#   'aqi': 27,
#   'status': '良好',
#   'pm25': 9.0,
#   'so2': 1.0,
#   'co': 0.22},
#  {'site_name': '新竹',
#   'county': '新竹市',
#   'aqi': 22,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 1.0,
#   'co': 0.22},
#  {'site_name': '竹東',
#   'county': '新竹縣',
#   'aqi': 31,
#   'status': '良好',
#   'pm25': 7.0,
#   'so2': 0.2,
#   'co': 0.16},
#  {'site_name': '湖口',
#   'county': '新竹縣',
#   'aqi': 44,
#   'status': '良好',
#   'pm25': 16.0,
#   'so2': 0.7,
#   'co': 0.19},
#  {'site_name': '龍潭',
#   'county': '桃園市',
#   'aqi': 25,
#   'status': '良好',
#   'pm25': 8.0,
#   'so2': 0.9,
#   'co': 0.19}]

# %%
import pandas as pd
df1 = pd.DataFrame(all_sites)
df1
# Out:
#     site_name county  aqi status  pm25  so2    co
# 0      屏東(枋山)    屏東縣   27     良好   9.0  0.3  0.06
# 1    大甲（日南國小）    臺中市   34     良好  11.0  0.6  0.23
# 2      新北(樹林)    新北市   57     普通  20.0  1.0  0.17
# 3      屏東（琉球）    屏東縣   36     良好  11.0  0.8  0.28
# 4      臺南（麻豆）    臺南市   33     良好   9.0  0.7  0.12
# ..        ...    ...  ...    ...   ...  ...   ...
# 995        頭份    苗栗縣   27     良好   9.0  1.0  0.22
# 996        新竹    新竹市   22     良好   7.0  1.0  0.22
# 997        竹東    新竹縣   31     良好   7.0  0.2  0.16
# 998        湖口    新竹縣   44     良好  16.0  0.7  0.19
# 999        龍潭    桃園市   25     良好   8.0  0.9  0.19
#
# [1000 rows x 7 columns]

# %%
df1[df1['aqi'] <= 13]
# Out:
#     site_name county  aqi status  pm25  so2    co
# 26         潮州    屏東縣   -1          7.0  0.9  0.00
# 111        潮州    屏東縣   -1          0.0  0.0  0.00
# 196        潮州    屏東縣   -1          0.0  0.0  0.00
# 281        潮州    屏東縣   -1          0.0  0.0  0.00
# 366        潮州    屏東縣   -1          0.0  0.0  0.00
# 451        潮州    屏東縣   -1          0.0  0.0  0.00
# 522        金門    金門縣   13     良好   6.0  1.0  0.07
# 536        潮州    屏東縣    9     良好   0.0  0.0  0.00
# 607        金門    金門縣   12     良好   5.0  0.9  0.08
# 691        馬公    澎湖縣   13     良好   7.0  0.9  0.16
# 692        金門    金門縣   13     良好   5.0  1.0  0.08
# 777        金門    金門縣   13     良好   4.0  0.9  0.08
# 862        金門    金門縣   13     良好   4.0  0.9  0.09
# 947        金門    金門縣   13     良好   3.0  0.8  0.00

# %% [markdown]
# ### Homework

# %%
youbike_url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

# %%
import requests
from requests import Response
youbike_url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

res:Response = requests.get(youbike_url)

if res.status_code == 200:
    print("下載成功")
else:
    print("下載失敗")


from pydantic import BaseModel,Field,field_validator,RootModel
class Site (BaseModel):
    站名:str = Field(alias='sna') 
    行政區域:str = Field(alias='sarea')
    時間:str = Field(alias='mday')
    位置:str = Field(alias='ar')
    狀態:bool = Field(alias='act')
    總數量:int = Field(alias='total')
    可借:int = Field(alias='available_rent_bikes')
    緯度:float = Field(alias='latitude')
    經度:float = Field(alias='longitude')     
    可還:int = Field(alias='available_return_bikes')

    @field_validator('站名',mode='before')
    @classmethod
    def get_name(cls,value:str) ->str:
         return value.split('_')[-1]   

class Youbick(RootModel):
    root:list[Site]


data = Youbick.model_validate_json(res.text)
all_sites = data.model_dump()


import pandas as pd
df = pd.DataFrame(all_sites)
df
# Out:
# 下載成功
#                  站名    行政區域                   時間             位置    狀態  總數量  \
# 0           捷運科技大樓站     大安區  2024-06-19 11:18:19    復興南路二段235號前  True   28
# 1       復興南路二段273號前     大安區  2024-06-19 11:14:15   復興南路二段273號西側  True   21
# 2         國北教大實小東側門     大安區  2024-06-19 11:18:19    和平東路二段96巷7號  True   16
# 3            和平公園東側     大安區  2024-06-19 11:03:20  和平東路二段118巷33號  True   11
# 4         辛亥復興路口西北側     大安區  2024-06-19 11:18:19     復興南路二段368號  True   16
# ...             ...     ...                  ...            ...   ...  ...
# 1422      臺大總圖書館西南側  臺大公館校區  2024-06-19 11:19:19       臺大圖書館西南側  True   30
# 1423        臺大黑森林西側  臺大公館校區  2024-06-19 11:17:29        臺大霖澤館南側  True   20
# 1424        臺大獸醫館南側  臺大公館校區  2024-06-19 11:14:15       臺大獸醫系館南側  True   24
# 1425      臺大新體育館東南側  臺大公館校區  2024-06-19 11:15:20        臺大體育館東側  True   40
# 1426  臺大明達館北側(員工宿舍)  臺大公館校區  2024-06-19 11:18:19       明達館北側前空地  True   18
#
#       可借        緯度         經度  可還
# 0      0  25.02605  121.54360  28
# 1      0  25.02565  121.54357  21
# 2      4  25.02429  121.54124  12
# 3      2  25.02351  121.54282   9
# 4      9  25.02153  121.54299   7
# ...   ..       ...        ...  ..
# 1422  26  25.01690  121.54031   1
# 1423  20  25.01995  121.54347   0
# 1424  19  25.01791  121.54242   0
# 1425  38  25.02112  121.53591   2
# 1426   9  25.01816  121.54469   9
#
# [1427 rows x 10 columns]
