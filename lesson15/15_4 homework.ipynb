# %%
labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
values = [20, 30, 45, 10]

# %%
import matplotlib.pyplot as plt

labels = 'Nokia', 'Samsung', 'Apple', 'Lumia'
values = [20, 30, 45, 10]
explode = [0.3,0, 0, 0]
colors = ['yellow', 'green', 'red', 'blue']
axes = figure.add_subplot(1, 1, 1)

figure = plt.figure(figsize=(5, 5), dpi=150, facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)

axes.pie(values, labels=labels,explode=explode,colors=colors)
axes.set_title('Market Survey')
plt.show()

# %%
import matplotlib.pyplot as plt

labels = 'Nokia', 'Samsung', 'Apple', 'Lumia'
values = [20, 30, 45, 10]
explode = [0.3,0, 0, 0]
colors = ['yellow', 'green', 'red', 'blue']
axes = figure.add_subplot(1, 1, 1)

figure = plt.figure(figsize=(5, 5), dpi=150, facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)

axes.pie(values, labels=labels,explode=explode,colors=colors,autopct='%.1f%%',startangle=180)
axes.set_title('Market Survey')
plt.show()

# %%
#labels = 'Nokia', 'Samsung', 'Apple', 'Lumia'
#values = [20, 30, 45, 10]

import matplotlib.pyplot as plt
labels = 'Nokia', 'Samsung', 'Apple', 'Lumia'
values = [20, 30, 45, 10]
explode = [0.3, 0, 0, 0]
colors = ['yellow', 'green', 'red', 'blue']

figure = plt.figure(figsize=(5, 5), dpi=150, facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)

axes.pie(values,labels=labels,explode=explode,colors=colors,autopct='%.1f%%',startangle=180,shadow={'ox': -0.01, 'oy': -0.01})
axes.set_title('Market Survey')
plt.show()

# %% [markdown]
# ### 同學答案

# %%
import matplotlib.pyplot as plt

labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
values = [20, 30, 45, 10]
explode = [0.3, 0, 0, 0]
colors = ['yellow', 'green', 'red', 'blue']

figure = plt.figure(figsize=(5, 5), dpi=150, facecolor='#FAF4FF')
axes = figure.add_subplot(1, 1, 1)
axes.pie(values,labels=labels,explode=explode,colors=colors,autopct='%.1f%%',startangle=180,shadow={'ox': -0.01, 'oy': -0.01})
axes.set_title('Market Survey',color ='black')

plt.show()

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())

#繪圖
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)

axes.plot(subject,values1,'bo--', label='student1')
axes.plot(subject,values2,'ro-.', label='student2')
axes.grid(axis='y')
axes.set_title("student1 vs student2")
axes.set_xlabel('subjects')
axes.set_ylabel('scores')
axes.legend()
print(axes.get_xticks())
print(axes.get_yticks())
labels = axes.get_xticklabels()
print(labels)
for label in labels:
    subject_name = label.get_text()
    score1 = student1[subject_name]
    x_value = label.get_position()[0]
    axes.annotate(str(score1),(x_value,score1+0.5))
    score2 = student2[subject_name]
    axes.annotate(str(score2),(x_value,score2+0.5))


plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [55. 60. 65. 70. 75. 80. 85. 90. 95.]
# [Text(0, 0, 'chinese'), Text(1, 0, 'english'), Text(2, 0, 'math'), Text(3, 0, 'history'), Text(4, 0, 'discover')]
