# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}

print(type(student1))
# Out:
# <class 'dict'>

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
print(keys)
# Out:
# dict_keys(['chinese', 'english', 'math', 'history', 'discover'])

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
print(values)
# Out:
# dict_values([78, 80, 92, 75, 85])

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())

subject,values1,values2
# Out:
# (['chinese', 'english', 'math', 'history', 'discover'],
#  [78, 80, 92, 75, 85],
#  [92, 60, 85, 62, 73])

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())

#繪圖
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)

axes.plot(subject,values1)
axes.plot(subject,values2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 10
#       7 values2 = list(student2.values())
#       9 #繪圖
# ---> 10 import matplotlib.pyplot as plt
#      12 figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
#      13 axes = figure.add_subplot(1, 1, 1)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())

#繪圖
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)

axes.plot(subject,values1,'bo--')
axes.plot(subject,values2,'ro-.')

plt.show()

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())

#繪圖
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)

axes.plot(subject,values1,'bo--')
axes.plot(subject,values2,'ro-.')
axes.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 10
#       7 values2 = list(student2.values())
#       9 #繪圖
# ---> 10 import matplotlib.pyplot as plt
#      12 figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
#      13 axes = figure.add_subplot(1, 1, 1)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())

#繪圖
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)

axes.plot(subject,values1,'bo--', label='student1')
axes.plot(subject,values2,'ro-.', label='student2')
axes.grid(axis='y')
axes.set_title("student1 vs student2")
axes.set_xlabel('subjects')
axes.set_ylabel('scores')
axes.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 10
#       7 values2 = list(student2.values())
#       9 #繪圖
# ---> 10 import matplotlib.pyplot as plt
#      12 figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
#      13 axes = figure.add_subplot(1, 1, 1)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())

#繪圖
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)

axes.plot(subject,values1,'bo--', label='student1')
axes.plot(subject,values2,'ro-.', label='student2')
axes.grid(axis='y')
axes.set_title("student1 vs student2")
axes.set_xlabel('subjects')
axes.set_ylabel('scores')
axes.legend()
print(axes.get_xticks())


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 values2 = list(student2.values())
#       9 #繪圖
# ---> 10 import matplotlib.pyplot as plt
#      12 figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
#      13 axes = figure.add_subplot(1, 1, 1)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())

#繪圖
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)
axes.plot(subject,values1,'bo--',label='student1')
axes.plot(subject,values2,'ro-.',label='student2')
axes.grid(axis='y')
axes.set_title("student1 vs student2")
axes.set_xlabel('subjects')
axes.set_ylabel('scores')
axes.legend()
#print(axes.get_xticks())
#print(axes.get_yticks())
labels = axes.get_xticklabels()
#print(labels)
for text in labels:
    subject_name = text.get_text()
    score1 = student1[subject_name]
    x_value = text.get_position()[0]
    axes.annotate(str(score1),(x_value,score1+0.5))
    score2 = student2[subject_name]
    axes.annotate(str(score2),(x_value,score2+0.5))
plt.show()

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())

#繪圖
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5),dpi=250,facecolor='#EEA9A9')
axes = figure.add_subplot(1, 1, 1)
axes.plot(subject,values1,'bo--',label='student1')
axes.plot(subject,values2,'ro-.',label='student2')
axes.grid(axis='y')
axes.set_title("student1 vs student2")
axes.set_xlabel('subjects')
axes.set_ylabel('scores')
axes.legend()
#print(axes.get_xticks())
#print(axes.get_yticks())
labels = axes.get_xticklabels()
#print(labels)
for text in labels:
    subject_name = text.get_text()
    score1 = student1[subject_name]
    x_value = text.get_position()[0]
    axes.annotate(str(score1),(x_value,score1+0.5))
    score2 = student2[subject_name]
    axes.annotate(str(score2),(x_value,score2+0.5))
plt.show()
